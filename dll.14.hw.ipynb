# %% [markdown]
# ## Задание
# 1. Реализуйте задачу машинного перевода с использованием transformer.
# Датасет: http://www.manythings.org/anki/

# %%
from io import open
import unicodedata
import string
import re
import random
import math
import torch
import torch as tr
import torch.nn as nn
import torch.nn.functional as F

# %%
dev = tr.device('cuda:0' if tr.cuda.is_available() else 'cpu')
device = dev
print(f"work on {(tr.cuda.get_device_name() if dev.type == 'cuda' else 'cpu')}")
# Out:
# work on GeForce GTX 1070

# %%
# !wget https://www.manythings.org/anki/rus-eng.zip
# !unzip rus-eng.zip

# %%
# !tail rus.txt

# %%
SOS_token = 0
EOS_token = 1


class Lang:
    def __init__(self, name):
        self.name = name
        self.word2index = {}
        self.word2count = {}
        self.index2word = {0: "SOS", 1: "EOS", 2:'MASK'}
        self.n_words = 3  # Count SOS and EOS and MASK

    def addSentence(self, sentence):
        for word in sentence.split(' '):
            self.addWord(word)

    def addWord(self, word):
        if word not in self.word2index:
            self.word2index[word] = self.n_words
            self.word2count[word] = 1
            self.index2word[self.n_words] = word
            self.n_words += 1
        else:
            self.word2count[word] += 1

# %%
# Turn a Unicode string to plain ASCII, thanks to
# http://stackoverflow.com/a/518232/2809427
def unicodeToAscii(s):
    return ''.join(c for c in unicodedata.normalize('NFD', s) if unicodedata.category(c) != 'Mn')

# Lowercase, trim, and remove non-letter characters
def normalizeString(s):
    s = unicodeToAscii(s.lower().strip())
    s = re.sub(r"([.!?])", r" \1", s)
    s = re.sub(r"[^a-zA-Zа-яА-Я.!?]+", r" ", s)
    return s

# %%
def readLangs(lang1, lang2, reverse=False):
    print("Reading lines...")

    # Read the file and split into lines
    lines = open('rus.txt', encoding='utf-8').read().strip().split('\n')

    # Split every line into pairs and normalize
    pairs = [[normalizeString(s) for s in l.split('\t')[:-1]] for l in lines]

    # Reverse pairs, make Lang instances
    if reverse:
        pairs = [list(reversed(p)) for p in pairs]
        input_lang = Lang(lang2)
        output_lang = Lang(lang1)
    else:
        input_lang = Lang(lang1)
        output_lang = Lang(lang2)

    return input_lang, output_lang, pairs

# %%
MAX_LENGTH = 10

eng_prefixes = (
    "i am ", "i m ",
    "he is", "he s ",
    "she is", "she s",
    "you are", "you re ",
    "we are", "we re ",
    "they are", "they re "
)


def filterPair(p):
    return len(p[0].split(' ')) < MAX_LENGTH and \
        len(p[1].split(' ')) < MAX_LENGTH and \
        p[1].startswith(eng_prefixes)


def filterPairs(pairs):
    return [pair for pair in pairs if filterPair(pair)]

# %%
def prepareData(lang1, lang2, reverse=False):
    input_lang, output_lang, pairs = readLangs(lang1, lang2, reverse)
    print("Read %s sentence pairs" % len(pairs))
    pairs = filterPairs(pairs)
    print("Trimmed to %s sentence pairs" % len(pairs))
    print("Counting words...")
    for pair in pairs:
        input_lang.addSentence(pair[0])
        output_lang.addSentence(pair[1])
    print("Counted words:")
    print(input_lang.name, input_lang.n_words)
    print(output_lang.name, output_lang.n_words)
    return input_lang, output_lang, pairs


# input_lang, output_lang, pairs = prepareData('eng', 'fra', True)
input_lang, output_lang, pairs = prepareData('eng', 'rus', True)

print(random.choice(pairs))
# Out:
# Reading lines...
# Read 429117 sentence pairs
# Trimmed to 25315 sentence pairs
# Counting words...
# Counted words:
# rus 9531
# eng 4112
# ['я иду к своеи бабушке .', 'i m going to my grandmother s .']

# %%
def indexesFromSentence(lang, sentence):
    return [lang.word2index[word] for word in sentence.split(' ')]

def tensorFromSentence(lang, sentence):
    indexes = indexesFromSentence(lang, sentence)
    indexes.append(EOS_token)
    return torch.tensor(indexes, dtype=torch.long, device=device).view(-1, 1)

def tensorsFromPair(pair):
    input_tensor = tensorFromSentence(input_lang, pair[0])
    target_tensor = tensorFromSentence(output_lang, pair[1])
    return (input_tensor, target_tensor)

# %%
def inds2text(inds):
    return ' '.join([output_lang.index2word[ind.item()] for ind in inds])

def inds2text2(inds):
    return ' '.join([input_lang.index2word[ind.item()] for ind in inds])


class PositionalEncoding(nn.Module):
    def __init__(self, d_model, dropout=0.1, max_len=5000):
        super(PositionalEncoding, self).__init__()
        self.dropout = nn.Dropout(p=dropout)
        pe = torch.zeros(max_len, d_model)
        position = torch.arange(0, max_len, dtype=torch.float).unsqueeze(1)
        div_term = torch.exp(torch.arange(0, d_model, 2).float() * (-math.log(10000.0) / d_model))
        pe[:, 0::2] = torch.sin(position * div_term)
        pe[:, 1::2] = torch.cos(position * div_term)
        pe = pe.unsqueeze(0).transpose(0, 1)
        self.register_buffer('pe', pe)

    def forward(self, x):
        x = x + self.pe[:x.size(0), :]
        return self.dropout(x)

# %%
class Trans1(tr.nn.Module):
    def __init__(self, n_classes_in, n_classes_out, n_emb, n_layers = 2, activ = tr.nn.LeakyReLU):
        super().__init__()
        self.emb_srs = tr.nn.Embedding(n_classes_in, n_emb)
        self.emb_tgt = tr.nn.Embedding(n_classes_out, n_emb)
        self.trans = tr.nn.Transformer(n_emb, num_encoder_layers = n_layers, num_decoder_layers = n_layers)
        self.activ = activ()
        self.pos_encoder = PositionalEncoding(n_emb, 0.1)
        self.fc = tr.nn.Linear(n_emb, n_classes_out)
        self.fc2 = tr.nn.Linear(n_classes_out, n_classes_out)

    def forward(self, srs, tgt, srs_mask = None, tgt_mask = None):

        if srs_mask: 
            srs_mask = self.trans.generate_square_subsequent_mask(srs.shape[0]).to(dev)
        if tgt_mask: 
            tgt_mask = self.trans.generate_square_subsequent_mask(tgt.shape[0]).to(dev)
            
        srs = self.emb_srs(srs)
        tgt = self.emb_tgt(tgt)

        srs = self.pos_encoder(srs)
        tgt = self.pos_encoder(tgt)

        x = self.trans(srs, tgt, tgt_mask = tgt_mask)
        x = self.fc(x)

        x = self.activ(x)
        x = self.fc2(x)

        return x

# %%
training_pairs = [tensorsFromPair(x) for x in pairs]

batch = tr.zeros(2, len(training_pairs), 10, 1) + 1
for i, x in enumerate(training_pairs):
    batch[0, i, :x[0].shape[0]] = x[0]
    batch[1, i, :x[1].shape[0]] = x[1]

batch_size = 500
train = tr.utils.data.DataLoader(batch.permute(1,0,2,3), batch_size = batch_size, shuffle = True)

# %%
n_classes_in = input_lang.n_words
n_classes_out = output_lang.n_words
n_emb = 128
n_layers = 2

model1 = Trans1(n_classes_in, n_classes_out, n_emb, n_layers).to(dev)
optim = tr.optim.Adam(model1.parameters())
crit = tr.nn.CrossEntropyLoss()

# %%
n_iters = 1000
n_prints = 100
loss = tr.tensor([10])
loss2 = tr.tensor([0])

model1.train()
for iter in range(n_iters):
    for data in train:    
        input_tensor = data[:,0].squeeze().long().to(dev)
        target_tensor = data[:,1].squeeze().long().to(dev)
        target_tensor2 = target_tensor.clone()
        m = tr.rand(target_tensor2.shape).to(dev)
        mask = m > (loss.item() / 5)**0.5

        target_tensor2[mask] = 2
        optim.zero_grad() 
        pred = model1(input_tensor, target_tensor2,)  #  True, True
        loss = crit(pred.reshape(-1, n_classes_out), target_tensor.reshape(-1))
        mask_sum = mask.sum()
        if mask_sum > 0:
            loss2 = crit(pred[mask].squeeze(), target_tensor[mask]) * 0.2
            loss += loss2
        else:
            loss2 *= 0
        # print(f'iter {iter}, loss = {loss.item(), loss2.item(), mask_sum.item()}')

        loss.backward()
        optim.step()

    if iter % (n_iters / n_prints) == 0:
        n = tr.randint(0, data.shape[0], (1,)).item()
        pred_text = inds2text(pred[n].max(dim=-1).indices)
        tgt_text =  inds2text(target_tensor[n])
        tgt2_text = inds2text(target_tensor2[n])
        srs_text =  inds2text2(input_tensor[n])
        # print(f'iter {iter}, loss = {loss.item()}')
        print(f"""iter {iter}, loss = {loss.item()} - {loss2.item()}, masks {mask_sum.item()},
                loss per word = {(loss.item() - loss2.item()) / tr.tensor(target_tensor.shape).prod() * 10000} 
                loss per mask = {(loss2.to(dev) / mask_sum).item() * 10000}
                \n{srs_text}\n{tgt_text}\n{tgt2_text}\n{pred_text}\n""")
# Out:
# iter 0, loss = 1.8850069046020508 - 0.5785824656486511, masks 1269,
#                 loss per word = 4.147378921508789
#                 loss per mask = 4.559357475955039
#
# он никогда еще не был влюблен . EOS EOS EOS
# he s never been in love before . EOS EOS
# he MASK never been MASK MASK MASK MASK MASK MASK
# he m never been . EOS EOS EOS EOS EOS
#
# iter 10, loss = 1.759853720664978 - 0.5636107921600342, masks 1337,
#                 loss per word = 3.7975964546203613
#                 loss per mask = 4.215488443151116
#
# его устраивает его текущее положение . EOS EOS EOS EOS
# he is content with his present state . EOS EOS
# MASK MASK content with MASK present state . MASK EOS
# i m content with . present state . EOS EOS
#
# iter 20, loss = 1.6946673393249512 - 0.5563330054283142, masks 1289,
#                 loss per word = 3.6137595176696777
#                 loss per mask = 4.316004633437842
#
# ты пьян . EOS EOS EOS EOS EOS EOS EOS
# you are drunk ! EOS EOS EOS EOS EOS EOS
# you are drunk ! MASK EOS MASK MASK MASK EOS
# you are drunk ! . EOS EOS EOS EOS EOS
#
# iter 30, loss = 1.6692875623703003 - 0.530316948890686, masks 1353,
#                 loss per word = 3.6157796382904053
#                 loss per mask = 3.9195636054500937
#
# мы чрезвычаино гордимся томом . EOS EOS EOS EOS EOS
# we re extremely proud of tom . EOS EOS EOS
# MASK re extremely MASK of tom MASK MASK MASK MASK
# i re extremely . of tom EOS EOS EOS EOS
#
# iter 40, loss = 1.7192049026489258 - 0.55242520570755, masks 1321,
#                 loss per word = 3.7040624618530273
#                 loss per mask = 4.181871481705457
#
# ты намного выше тома . EOS EOS EOS EOS EOS
# you re a lot taller than tom . EOS EOS
# you re a lot taller than tom . EOS MASK
# you re a lot taller than tom . EOS EOS
#
# iter 50, loss = 1.7272003889083862 - 0.5399954319000244, masks 1385,
#                 loss per word = 3.768904447555542
#                 loss per mask = 3.8988838787190616
#
# они о тебе говорят том . EOS EOS EOS EOS
# they re talking about you tom . EOS EOS EOS
# they re MASK MASK MASK tom . EOS MASK EOS
# they re not . . tom . EOS EOS EOS
#
# iter 60, loss = 1.5872001647949219 - 0.5070583820343018, masks 1342,
#                 loss per word = 3.4290213584899902
#                 loss per mask = 3.7783783045597374
#
# простите если беспокою вас . EOS EOS EOS EOS EOS
# i m sorry if i m bothering you . EOS
# i m sorry MASK i m bothering MASK MASK MASK
# i m sorry . i m bothering EOS EOS EOS
#
# iter 70, loss = 1.7483315467834473 - 0.5548829436302185, masks 1355,
#                 loss per word = 3.7887253761291504
#                 loss per mask = 4.095077165402472
#
# я не пострадала . EOS EOS EOS EOS EOS EOS
# i m not hurt . EOS EOS EOS EOS EOS
# i MASK not hurt MASK EOS MASK EOS EOS MASK
# i m not hurt . EOS EOS EOS EOS EOS
#
# iter 80, loss = 1.6421701908111572 - 0.5283715128898621, masks 1328,
#                 loss per word = 3.5358686447143555
#                 loss per mask = 3.978701133746654
#
# мы хотим пить . EOS EOS EOS EOS EOS EOS
# we re thirsty . EOS EOS EOS EOS EOS EOS
# MASK MASK thirsty . MASK EOS MASK EOS MASK MASK
# i m thirsty . . EOS EOS EOS EOS EOS
#
# iter 90, loss = 1.6562573909759521 - 0.5422104001045227, masks 1294,
#                 loss per word = 3.5366570949554443
#                 loss per mask = 4.190188483335078
#
# она в ваннои . EOS EOS EOS EOS EOS EOS
# she is in the bathroom . EOS EOS EOS EOS
# she is MASK the MASK MASK EOS MASK EOS EOS
# she is not the . EOS EOS EOS EOS EOS
#
# iter 100, loss = 1.6618399620056152 - 0.5458565354347229, masks 1288,
#                 loss per word = 3.542804718017578
#                 loss per mask = 4.238016554154456
#
# я старше твоего брата . EOS EOS EOS EOS EOS
# i m older than your brother . EOS EOS EOS
# i m older MASK MASK brother . EOS MASK EOS
# i m older . . brother . EOS EOS EOS
#
# iter 110, loss = 1.6711702346801758 - 0.5390123128890991, masks 1323,
#                 loss per word = 3.5941519737243652
#                 loss per mask = 4.074167227372527
#
# ты совсем как твои отец . EOS EOS EOS EOS
# you re just like your father . EOS EOS EOS
# MASK MASK MASK like your MASK MASK MASK EOS MASK
# i m not like your EOS EOS EOS EOS EOS
#
# iter 120, loss = 1.6918044090270996 - 0.5387914776802063, masks 1348,
#                 loss per word = 3.660358428955078
#                 loss per mask = 3.996969317086041
#
# я опять опоздал да ? EOS EOS EOS EOS EOS
# i m late again aren t i ? EOS EOS
# i m late MASK aren MASK MASK MASK MASK EOS
# i m late . aren EOS EOS EOS EOS EOS
#
# iter 130, loss = 1.7286615371704102 - 0.5353994369506836, masks 1404,
#                 loss per word = 3.7881336212158203
#                 loss per mask = 3.8133864291012287
#
# мне это не интересно . EOS EOS EOS EOS EOS
# i m not interested in that . EOS EOS EOS
# i m not interested in that . MASK EOS EOS
# i m not interested in that . EOS EOS EOS
#
# iter 140, loss = 1.7410356998443604 - 0.5489725470542908, masks 1368,
#                 loss per word = 3.7843270301818848
#                 loss per mask = 4.012957215309143
#
# я иду за тобои . EOS EOS EOS EOS EOS
# i m coming for you . EOS EOS EOS EOS
# i m coming MASK you . EOS EOS EOS EOS
# i m coming . you . EOS EOS EOS EOS
#
# iter 150, loss = 1.7032434940338135 - 0.5405718684196472, masks 1355,
#                 loss per word = 3.6910207271575928
#                 loss per mask = 3.989460237789899
#
# мои любимыи предмет биология . EOS EOS EOS EOS EOS
# i m favorite subject is biology . EOS EOS EOS
# MASK MASK MASK MASK MASK biology MASK EOS MASK EOS
# i m not . . biology EOS EOS EOS EOS
#
# iter 160, loss = 1.787539005279541 - 0.5699114203453064, masks 1346,
#                 loss per word = 3.8654839992523193
#                 loss per mask = 4.234111693222076
#
# я в такои же ситуации . EOS EOS EOS EOS
# i m in the same boat . EOS EOS EOS
# i m MASK the same MASK MASK EOS EOS MASK
# i m not the same EOS EOS EOS EOS EOS
#
# iter 170, loss = 1.613269567489624 - 0.5225329995155334, masks 1315,
#                 loss per word = 3.462655782699585
#                 loss per mask = 3.97363502997905
#
# я племянник тома . EOS EOS EOS EOS EOS EOS
# i m tom s nephew . EOS EOS EOS EOS
# MASK MASK tom s MASK . EOS EOS MASK EOS
# i m tom s . . EOS EOS EOS EOS
#
# iter 180, loss = 1.7806875705718994 - 0.5620397925376892, masks 1366,
#                 loss per word = 3.868722677230835
#                 loss per mask = 4.114493494853377
#
# я уже не занята . EOS EOS EOS EOS EOS
# i m not busy anymore . EOS EOS EOS EOS
# i MASK not busy anymore MASK MASK EOS MASK MASK
# i m not busy anymore EOS EOS EOS EOS EOS
#
# iter 190, loss = 1.614922285079956 - 0.5180166363716125, masks 1334,
#                 loss per word = 3.4822402000427246
#                 loss per mask = 3.8831832353025675
#
# я занят так как делаю домашнюю работу . EOS EOS
# i m busy doing homework . EOS EOS EOS EOS
# i m busy MASK homework . EOS EOS EOS EOS
# i m busy . homework . EOS EOS EOS EOS
#
# iter 200, loss = 1.6896257400512695 - 0.5403344631195068, masks 1340,
#                 loss per word = 3.6485435962677
#                 loss per mask = 4.032346769236028
#
# я пьяныи . EOS EOS EOS EOS EOS EOS EOS
# i m loaded . EOS EOS EOS EOS EOS EOS
# i MASK loaded MASK EOS MASK EOS EOS EOS MASK
# i m loaded . EOS EOS EOS EOS EOS EOS
#
# iter 210, loss = 1.7153146266937256 - 0.5392434000968933, masks 1374,
#                 loss per word = 3.7335588932037354
#                 loss per mask = 3.924624470528215
#
# они иностранцы . EOS EOS EOS EOS EOS EOS EOS
# they re foreigners . EOS EOS EOS EOS EOS EOS
# MASK re MASK MASK EOS EOS EOS MASK EOS MASK
# i re not . EOS EOS EOS EOS EOS EOS
#
# iter 220, loss = 1.759360671043396 - 0.5514358282089233, masks 1380,
#                 loss per word = 3.834681987762451
#                 loss per mask = 3.9959116838872433
#
# я посылаю инвоис по факсу . EOS EOS EOS EOS
# i am sending the invoice by fax . EOS EOS
# MASK am MASK MASK invoice MASK MASK . EOS MASK
# i am not . invoice EOS EOS . EOS EOS
#
# iter 230, loss = 1.5417441129684448 - 0.5079997777938843, masks 1282,
#                 loss per word = 3.2817277908325195
#                 loss per mask = 3.9625566569156945
#
# у нас чаи закончился . EOS EOS EOS EOS EOS
# we re out of tea . EOS EOS EOS EOS
# we re out MASK tea MASK MASK MASK EOS EOS
# we re out to tea EOS EOS EOS EOS EOS
# iter 240, loss = 1.637103796005249 - 0.5287327170372009, masks 1320,
#                 loss per word = 3.5186378955841064
#                 loss per mask = 4.0055508725345135
#
# я рад что вы вернулись . EOS EOS EOS EOS
# i m glad you got back . EOS EOS EOS
# i MASK glad MASK MASK back . MASK MASK EOS
# i m glad . . back . EOS EOS EOS
#
# iter 250, loss = 1.6466577053070068 - 0.5192140936851501, masks 1368,
#                 loss per word = 3.579185962677002
#                 loss per mask = 3.795424709096551
#
# мы оба говорим правду . EOS EOS EOS EOS EOS
# we re both telling the truth . EOS EOS EOS
# we re MASK MASK MASK MASK . MASK EOS MASK
# we re not . . EOS . EOS EOS EOS
#
# iter 260, loss = 1.7395315170288086 - 0.5356320738792419, masks 1416,
#                 loss per word = 3.8219027519226074
#                 loss per mask = 3.7827124469913542
#
# жду твоего ответа . EOS EOS EOS EOS EOS EOS
# i m waiting for your answer . EOS EOS EOS
# MASK m MASK for your answer MASK EOS MASK MASK
# i m not for your answer EOS EOS EOS EOS
#
# iter 270, loss = 1.6632208824157715 - 0.5310072898864746, masks 1343,
#                 loss per word = 3.5943286418914795
#                 loss per mask = 3.95388895412907
#
# вы никогда не опаздываете . EOS EOS EOS EOS EOS
# you re never late . EOS EOS EOS EOS EOS
# MASK MASK MASK late . MASK MASK MASK MASK EOS
# i m not late . EOS EOS EOS EOS EOS
#
# iter 280, loss = 1.6843067407608032 - 0.5345627069473267, masks 1355,
#                 loss per word = 3.6499810218811035
#                 loss per mask = 3.945112111978233
#
# вы мерзавец . EOS EOS EOS EOS EOS EOS EOS
# you re scum . EOS EOS EOS EOS EOS EOS
# MASK MASK scum . EOS MASK EOS EOS MASK EOS
# i m scum . EOS EOS EOS EOS EOS EOS
#
# iter 290, loss = 1.7374987602233887 - 0.5559244751930237, masks 1339,
#                 loss per word = 3.7510294914245605
#                 loss per mask = 4.151788598392159
#
# я рад что вы заговорили об этом . EOS EOS
# i m glad you brought this up . EOS EOS
# MASK m glad MASK MASK this MASK . MASK MASK
# i m glad . . this EOS . EOS EOS
#
# iter 300, loss = 1.6698124408721924 - 0.5428159832954407, masks 1308,
#                 loss per word = 3.5777664184570312
#                 loss per mask = 4.149969317950308
#
# вы напрашиваетесь на неприятности . EOS EOS EOS EOS EOS
# you re asking for trouble . EOS EOS EOS EOS
# you MASK MASK for trouble MASK MASK MASK EOS EOS
# you m not for trouble EOS EOS EOS EOS EOS
#
# iter 310, loss = 1.68882417678833 - 0.5403539538383484, masks 1339,
#                 loss per word = 3.645936965942383
#                 loss per mask = 4.03550366172567
#
# он боится летать на самолете . EOS EOS EOS EOS
# he is afraid to fly in an airplane . EOS
# MASK is MASK to MASK in an airplane . MASK
# i is not to . in an airplane . EOS
#
# iter 320, loss = 1.724070429801941 - 0.5499556064605713, masks 1345,
#                 loss per word = 3.727348566055298
#                 loss per mask = 4.088889400009066
#
# нам придется вместе работать . EOS EOS EOS EOS EOS
# we re going to have to work together . EOS
# MASK MASK MASK to MASK to MASK together . MASK
# i m not to . to EOS together . EOS
#
# iter 330, loss = 1.6216814517974854 - 0.5149490833282471, masks 1354,
#                 loss per word = 3.5134358406066895
#                 loss per mask = 3.803168947342783
#
# его считают надежным человеком . EOS EOS EOS EOS EOS
# he is considered trustworthy . EOS EOS EOS EOS EOS
# MASK MASK considered trustworthy . EOS MASK EOS MASK EOS
# i m considered trustworthy . EOS EOS EOS EOS EOS
#
# iter 340, loss = 1.6071263551712036 - 0.5129075050354004, masks 1344,
#                 loss per word = 3.473710298538208
#                 loss per mask = 3.816276148427278
#
# мы разочарованы результатами . EOS EOS EOS EOS EOS EOS
# we re disappointed with the results . EOS EOS EOS
# we re MASK with MASK MASK . EOS MASK EOS
# we re not with . EOS . EOS EOS EOS
#
# iter 350, loss = 1.615940809249878 - 0.5108028054237366, masks 1363,
#                 loss per word = 3.5083746910095215
#                 loss per mask = 3.747636219486594
#
# вы еще не умерли . EOS EOS EOS EOS EOS
# you re not dead yet . EOS EOS EOS EOS
# MASK MASK MASK MASK yet MASK EOS EOS EOS EOS
# i m not . yet EOS EOS EOS EOS EOS
#
# iter 360, loss = 1.6792192459106445 - 0.5318787097930908, masks 1359,
#                 loss per word = 3.642350673675537
#                 loss per mask = 3.9137506973929703
#
# тебя не пригласили . EOS EOS EOS EOS EOS EOS
# you re not invited . EOS EOS EOS EOS EOS
# you re not invited MASK MASK MASK EOS EOS EOS
# you re not invited . EOS EOS EOS EOS EOS
#
# iter 370, loss = 1.6511367559432983 - 0.5378583669662476, masks 1303,
#                 loss per word = 3.53421688079834
#                 loss per mask = 4.127846332266927
#
# я привык жить один . EOS EOS EOS EOS EOS
# i am accustomed to living alone . EOS EOS EOS
# i am accustomed MASK living alone . EOS MASK MASK
# i am accustomed . living alone . EOS EOS EOS
#
# iter 380, loss = 1.7334296703338623 - 0.5515450835227966, masks 1350,
#                 loss per word = 3.752014398574829
#                 loss per mask = 4.085519176442176
#
# вы все еще выше меня . EOS EOS EOS EOS
# you re still taller than me . EOS EOS EOS
# MASK re MASK taller MASK me MASK EOS MASK MASK
# i re not taller . me EOS EOS EOS EOS
#
# iter 390, loss = 1.7816104888916016 - 0.5674477219581604, masks 1348,
#                 loss per word = 3.854485034942627
#                 loss per mask = 4.2095527169294655
#
# я сегодня очень устал . EOS EOS EOS EOS EOS
# i m very tired today . EOS EOS EOS EOS
# i m MASK MASK MASK MASK EOS MASK EOS MASK
# i m not . . EOS EOS EOS EOS EOS
#
# iter 400, loss = 1.682203769683838 - 0.5238390564918518, masks 1393,
#                 loss per word = 3.6773483753204346
#                 loss per mask = 3.760510007850826
#
# я привык к подобнои работе . EOS EOS EOS EOS
# i m used to this kind of work . EOS
# i m MASK to MASK kind MASK MASK . MASK
# i m not to . kind EOS EOS . EOS
#
# iter 410, loss = 1.6157841682434082 - 0.5391615629196167, masks 1258,
#                 loss per word = 3.41784930229187
#                 loss per mask = 4.285862960387021
#
# вы лжете мне . EOS EOS EOS EOS EOS EOS
# you are lying to me . EOS EOS EOS EOS
# you MASK lying MASK me . EOS EOS MASK EOS
# you m lying to me . EOS EOS EOS EOS
#
# iter 420, loss = 1.6207523345947266 - 0.5318070650100708, masks 1290,
#                 loss per word = 3.4569690227508545
#                 loss per mask = 4.122535465285182
#
# я больше не уставшая . EOS EOS EOS EOS EOS
# i am no longer tired . EOS EOS EOS EOS
# MASK am no longer tired . EOS EOS EOS EOS
# i am no longer tired . EOS EOS EOS EOS
#
# iter 430, loss = 1.6671931743621826 - 0.5342473387718201, masks 1336,
#                 loss per word = 3.5966532230377197
#                 loss per mask = 3.9988572825677693
#
# мне вроде как неудобно . EOS EOS EOS EOS EOS
# i m kind of uncomfortable . EOS EOS EOS EOS
# MASK m kind MASK uncomfortable MASK EOS EOS MASK EOS
# i m kind . uncomfortable EOS EOS EOS EOS EOS
#
# iter 440, loss = 1.643728256225586 - 0.5467330813407898, masks 1264,
#                 loss per word = 3.4825239181518555
#                 loss per mask = 4.3254200136289
#
# вы не едете . EOS EOS EOS EOS EOS EOS
# you re not going . EOS EOS EOS EOS EOS
# you re MASK MASK . MASK MASK EOS EOS EOS
# you re not . . EOS EOS EOS EOS EOS
#
# iter 450, loss = 1.6658878326416016 - 0.5343722701072693, masks 1334,
#                 loss per word = 3.5921125411987305
#                 loss per mask = 4.005789232905954
#
# мы оба из бостона . EOS EOS EOS EOS EOS
# we are both from boston . EOS EOS EOS EOS
# we MASK MASK from boston . EOS MASK EOS EOS
# we m not from boston . EOS EOS EOS EOS
#
# iter 460, loss = 1.6260128021240234 - 0.5223801732063293, masks 1331,
#                 loss per word = 3.5035955905914307
#                 loss per mask = 3.9247196400538087
#
# ты в хорошеи форме . EOS EOS EOS EOS EOS
# you re in good shape . EOS EOS EOS EOS
# MASK MASK MASK good MASK MASK EOS MASK MASK MASK
# i m not good . EOS EOS EOS EOS EOS
# iter 470, loss = 1.7152987718582153 - 0.5445715188980103, masks 1354,
#                 loss per word = 3.7165944576263428
#                 loss per mask = 4.02194622438401
#
# ты такои упрямыи . EOS EOS EOS EOS EOS EOS
# you re so stubborn . EOS EOS EOS EOS EOS
# you MASK so stubborn MASK MASK EOS MASK MASK MASK
# you m so stubborn . EOS EOS EOS EOS EOS
#
# iter 480, loss = 1.6020193099975586 - 0.5191721320152283, masks 1314,
#                 loss per word = 3.4376096725463867
#                 loss per mask = 3.9510815986432135
#
# она не безденежная . EOS EOS EOS EOS EOS EOS
# she s not penniless . EOS EOS EOS EOS EOS
# she s MASK MASK MASK MASK EOS MASK EOS MASK
# she s not . . EOS EOS EOS EOS EOS
#
# iter 490, loss = 1.6931147575378418 - 0.5145402550697327, masks 1443,
#                 loss per word = 3.741506338119507
#                 loss per mask = 3.5657675471156836
#
# вы даже не пытаетесь . EOS EOS EOS EOS EOS
# you aren t even trying . EOS EOS EOS EOS
# you aren MASK MASK trying . MASK MASK EOS EOS
# you aren not . trying . EOS EOS EOS EOS
#
# iter 500, loss = 1.6682078838348389 - 0.5359338521957397, masks 1331,
#                 loss per word = 3.5945205688476562
#                 loss per mask = 4.026550450362265
#
# у меня сегодня плохои день . EOS EOS EOS EOS
# i m having a bad day . EOS EOS EOS
# MASK m having MASK MASK MASK . EOS MASK EOS
# i m having . . EOS . EOS EOS EOS
#
# iter 510, loss = 1.6533942222595215 - 0.5314425826072693, masks 1330,
#                 loss per word = 3.561750888824463
#                 loss per mask = 3.995808947365731
#
# я больше не ребенок . EOS EOS EOS EOS EOS
# i m not a child anymore . EOS EOS EOS
# MASK m MASK a child anymore . MASK EOS MASK
# i m not a child anymore . EOS EOS EOS
#
# iter 520, loss = 1.557605504989624 - 0.5183740258216858, masks 1263,
#                 loss per word = 3.299147605895996
#                 loss per mask = 4.104307445231825
#
# мои рост пять футов два дюима . EOS EOS EOS
# i am five feet two inches tall . EOS EOS
# MASK am five feet two MASK tall MASK EOS MASK
# i am five feet two EOS tall EOS EOS EOS
#
# iter 530, loss = 1.6899362802505493 - 0.5493580102920532, masks 1308,
#                 loss per word = 3.6208832263946533
#                 loss per mask = 4.199984832666814
#
# вы всегда опаздываете . EOS EOS EOS EOS EOS EOS
# you re always late . EOS EOS EOS EOS EOS
# you re MASK MASK . EOS EOS MASK EOS EOS
# you re not . . EOS EOS EOS EOS EOS
#
# iter 540, loss = 1.7997052669525146 - 0.5560634732246399, masks 1409,
#                 loss per word = 3.9480693340301514
#                 loss per mask = 3.9465114241465926
#
# это вы наняли тома . EOS EOS EOS EOS EOS
# you re the one who hired tom . EOS EOS
# MASK re the MASK MASK hired tom . EOS EOS
# i re the . . hired tom . EOS EOS
#
# iter 550, loss = 1.6013290882110596 - 0.5126192569732666, masks 1338,
#                 loss per word = 3.456221580505371
#                 loss per mask = 3.8312352262437344
#
# я непопулярная . EOS EOS EOS EOS EOS EOS EOS
# i m unpopular . EOS EOS EOS EOS EOS EOS
# i m MASK . EOS EOS EOS EOS EOS EOS
# i m not . EOS EOS EOS EOS EOS EOS
#
# iter 560, loss = 1.7318663597106934 - 0.5385305285453796, masks 1396,
#                 loss per word = 3.78836727142334
#                 loss per mask = 3.857668489217758
#
# она выше чем он . EOS EOS EOS EOS EOS
# she s taller than him . EOS EOS EOS EOS
# MASK MASK taller than him MASK MASK EOS EOS EOS
# i m taller than him EOS EOS EOS EOS EOS
#
# iter 570, loss = 1.6770906448364258 - 0.534944474697113, masks 1345,
#                 loss per word = 3.6258604526519775
#                 loss per mask = 3.977282322011888
#
# ты напрасно тратишь мое время . EOS EOS EOS EOS
# you re wasting my time . EOS EOS EOS EOS
# MASK MASK wasting my MASK MASK EOS MASK MASK MASK
# i m wasting my . EOS EOS EOS EOS EOS
#
# iter 580, loss = 1.6849298477172852 - 0.5291646122932434, masks 1376,
#                 loss per word = 3.669095993041992
#                 loss per mask = 3.845673054456711
#
# мы упрямые . EOS EOS EOS EOS EOS EOS EOS
# we re stubborn . EOS EOS EOS EOS EOS EOS
# MASK MASK stubborn MASK MASK MASK EOS EOS EOS MASK
# i m stubborn . . EOS EOS EOS EOS EOS
#
# iter 590, loss = 1.590195655822754 - 0.5171896815299988, masks 1307,
#                 loss per word = 3.4063680171966553
#                 loss per mask = 3.9570749504491687
#
# сеичас я в старом замке . EOS EOS EOS EOS
# i am now in an old castle . EOS EOS
# MASK am now MASK an old MASK MASK EOS EOS
# i am now . an old EOS EOS EOS EOS
#
# iter 600, loss = 1.7710292339324951 - 0.548543393611908, masks 1404,
#                 loss per word = 3.8809070587158203
#                 loss per mask = 3.907004138454795
#
# это ты мне сказал . EOS EOS EOS EOS EOS
# you re the one who told me that . EOS
# you MASK the one MASK MASK MASK that . EOS
# you m the one . EOS EOS that . EOS
#
# iter 610, loss = 1.6719748973846436 - 0.5327964425086975, masks 1347,
#                 loss per word = 3.6164395809173584
#                 loss per mask = 3.9554302929900587
#
# я буду заниматься ежедневно . EOS EOS EOS EOS EOS
# i m going to exercise every day . EOS EOS
# MASK MASK going to MASK every MASK MASK EOS EOS
# i m going to . every EOS EOS EOS EOS
#
# iter 620, loss = 1.650848388671875 - 0.5353745818138123, masks 1312,
#                 loss per word = 3.5411863327026367
#                 loss per mask = 4.080598882865161
#
# этот дом построил я . EOS EOS EOS EOS EOS
# i m the one who built this house . EOS
# MASK MASK the one who MASK MASK house MASK MASK
# i m the one who EOS EOS house EOS EOS
#
# iter 630, loss = 1.5429396629333496 - 0.493175745010376, masks 1341,
#                 loss per word = 3.3325839042663574
#                 loss per mask = 3.67767148418352
#
# я рад что вы здесь . EOS EOS EOS EOS
# i m glad you re here . EOS EOS EOS
# i m glad MASK MASK MASK . EOS EOS EOS
# i m glad . . EOS . EOS EOS EOS
#
# iter 640, loss = 1.580315113067627 - 0.506033718585968, masks 1337,
#                 loss per word = 3.410417079925537
#                 loss per mask = 3.7848445936106145
#
# ты в хорошеи форме . EOS EOS EOS EOS EOS
# you re in good shape . EOS EOS EOS EOS
# MASK re MASK MASK MASK . MASK EOS MASK MASK
# i re not . . . EOS EOS EOS EOS
#
# iter 650, loss = 1.7123432159423828 - 0.5515176057815552, masks 1326,
#                 loss per word = 3.6851603984832764
#                 loss per mask = 4.1592580964788795
#
# ты деиствительно все хорошеешь и хорошеешь . EOS EOS EOS
# you re really getting prettier and prettier . EOS EOS
# you re MASK getting prettier MASK MASK . EOS EOS
# you re not getting prettier EOS EOS . EOS EOS
#
# iter 660, loss = 1.6197230815887451 - 0.5164067149162292, masks 1346,
#                 loss per word = 3.502591371536255
#                 loss per mask = 3.836602554656565
#
# вы гении . EOS EOS EOS EOS EOS EOS EOS
# you are a genius . EOS EOS EOS EOS EOS
# you MASK MASK genius MASK EOS MASK MASK MASK EOS
# you m not genius . EOS EOS EOS EOS EOS
#
# iter 670, loss = 1.6869035959243774 - 0.5300493240356445, masks 1375,
#                 loss per word = 3.672553062438965
#                 loss per mask = 3.8549042074009776
#
# я боюсь он не может приити . EOS EOS EOS
# i m afraid he cannot come . EOS EOS EOS
# i MASK afraid he MASK MASK MASK MASK MASK MASK
# i m afraid he . EOS EOS EOS EOS EOS
#
# iter 680, loss = 1.5828959941864014 - 0.5021267533302307, masks 1356,
#                 loss per word = 3.431013584136963
#                 loss per mask = 3.7029996747151017
#
# я уверен том сеичас об этом жалеет . EOS EOS
# i m sure tom regrets it now . EOS EOS
# i m MASK tom regrets it now . EOS EOS
# i m not tom regrets it now . EOS EOS
#
# iter 690, loss = 1.7993321418762207 - 0.565058171749115, masks 1376,
#                 loss per word = 3.9183297157287598
#                 loss per mask = 4.106527485419065
#
# ты единственныи канадец в нашеи школе . EOS EOS EOS
# you re the only canadian in our school . EOS
# MASK re MASK only canadian in MASK MASK . EOS
# i re not only canadian in EOS EOS . EOS
#
# iter 700, loss = 1.6456564664840698 - 0.5324358940124512, masks 1317,
#                 loss per word = 3.5340332984924316
#                 loss per mask = 4.042793298140168
#
# я немного замерз . EOS EOS EOS EOS EOS EOS
# i m a little cold . EOS EOS EOS EOS
# i MASK a little MASK . EOS EOS MASK EOS
# i m a little . . EOS EOS EOS EOS
# iter 710, loss = 1.665461778640747 - 0.5410787463188171, masks 1309,
#                 loss per word = 3.569469451904297
#                 loss per mask = 4.133527399972081
#
# мы не собираемся ждать тома . EOS EOS EOS EOS
# we re not going to wait for tom . EOS
# we re MASK going MASK MASK for MASK . EOS
# we re not going EOS EOS for EOS . EOS
#
# iter 720, loss = 1.731485366821289 - 0.5400165319442749, masks 1390,
#                 loss per word = 3.782440662384033
#                 loss per mask = 3.8850109558552504
#
# она в безопасности . EOS EOS EOS EOS EOS EOS
# she is out of danger . EOS EOS EOS EOS
# MASK MASK MASK of danger . EOS MASK MASK EOS
# i m not of danger . EOS EOS EOS EOS
#
# iter 730, loss = 1.7048298120498657 - 0.5457501411437988, masks 1338,
#                 loss per word = 3.6796178817749023
#                 loss per mask = 4.078850033693016
#
# ты чувствительныи . EOS EOS EOS EOS EOS EOS EOS
# you re sensitive . EOS EOS EOS EOS EOS EOS
# you re MASK MASK EOS MASK EOS EOS EOS EOS
# you re not . EOS EOS EOS EOS EOS EOS
#
# iter 740, loss = 1.7695268392562866 - 0.5690556764602661, masks 1329,
#                 loss per word = 3.8110194206237793
#                 loss per mask = 4.2818335350602865
#
# они очень важные люди . EOS EOS EOS EOS EOS
# they are very important people . EOS EOS EOS EOS
# they are MASK MASK MASK . EOS EOS EOS EOS
# they are not . . . EOS EOS EOS EOS
#
# iter 750, loss = 1.7112247943878174 - 0.5439295768737793, masks 1352,
#                 loss per word = 3.7056989669799805
#                 loss per mask = 4.023147630505264
#
# он обожает такого сорта музыку . EOS EOS EOS EOS
# he is fond of this kind of music . EOS
# he MASK MASK of MASK kind of music MASK MASK
# he m not of . kind of music EOS EOS
#
# iter 760, loss = 1.5804805755615234 - 0.5090474486351013, masks 1326,
#                 loss per word = 3.401374578475952
#                 loss per mask = 3.8389701512642205
#
# я готов помочь вам . EOS EOS EOS EOS EOS
# i am willing to help you . EOS EOS EOS
# MASK MASK willing to MASK MASK . MASK EOS EOS
# i m willing to . EOS . EOS EOS EOS
#
# iter 770, loss = 1.6828231811523438 - 0.5295588374137878, masks 1372,
#                 loss per word = 3.661156177520752
#                 loss per mask = 3.8597584352828562
#
# я все еще жду когда это произоидет . EOS EOS
# i m still waiting for it to happen . EOS
# MASK m still MASK for it MASK happen . MASK
# i m still . for it EOS happen . EOS
#
# iter 780, loss = 1.6738357543945312 - 0.5304332375526428, masks 1358,
#                 loss per word = 3.6298491954803467
#                 loss per mask = 3.905988414771855
#
# я гораздо старше вас . EOS EOS EOS EOS EOS
# i m much older than you are . EOS EOS
# i MASK much MASK than you MASK . MASK MASK
# i m much . than you EOS . EOS EOS
#
# iter 790, loss = 1.6287592649459839 - 0.5109559297561646, masks 1378,
#                 loss per word = 3.548581838607788
#                 loss per mask = 3.707953146658838
#
# я из фбр . EOS EOS EOS EOS EOS EOS
# i m from the fbi . EOS EOS EOS EOS
# MASK MASK from the MASK MASK MASK EOS EOS EOS
# i m from the . EOS EOS EOS EOS EOS
#
# iter 800, loss = 1.665645956993103 - 0.5273102521896362, masks 1360,
#                 loss per word = 3.6137640476226807
#                 loss per mask = 3.8772812695242465
#
# я еще не проголодался . EOS EOS EOS EOS EOS
# i m still not hungry . EOS EOS EOS EOS
# MASK MASK MASK MASK hungry . EOS EOS MASK EOS
# i m not . hungry . EOS EOS EOS EOS
#
# iter 810, loss = 1.597029447555542 - 0.5262161493301392, masks 1282,
#                 loss per word = 3.399407148361206
#                 loss per mask = 4.104650288354605
#
# я хочу есть потому что не завтракал . EOS EOS
# i m hungry because i skipped breakfast . EOS EOS
# MASK m hungry MASK i MASK breakfast MASK MASK EOS
# i m hungry . i EOS breakfast EOS EOS EOS
#
# iter 820, loss = 1.8074462413787842 - 0.5522246956825256, masks 1432,
#                 loss per word = 3.984830379486084
#                 loss per mask = 3.856317780446261
#
# мы уже состоим в браке . EOS EOS EOS EOS
# we re already married . EOS EOS EOS EOS EOS
# we MASK already married MASK MASK EOS EOS EOS EOS
# we m already married . EOS EOS EOS EOS EOS
#
# iter 830, loss = 1.5277235507965088 - 0.49586042761802673, masks 1311,
#                 loss per word = 3.2757556438446045
#                 loss per mask = 3.7823067395947874
#
# я больше тебя . EOS EOS EOS EOS EOS EOS
# i m bigger than you . EOS EOS EOS EOS
# i MASK bigger MASK you . EOS MASK MASK EOS
# i m bigger . you . EOS EOS EOS EOS
#
# iter 840, loss = 1.7038593292236328 - 0.5473894476890564, masks 1331,
#                 loss per word = 3.671332597732544
#                 loss per mask = 4.112618044018745
#
# я счастлив что теперь все закончилось . EOS EOS EOS
# i m happy it s over now . EOS EOS
# i m happy MASK s over now MASK EOS MASK
# i m happy . s over now EOS EOS EOS
#
# iter 850, loss = 1.6717197895050049 - 0.5355649590492249, masks 1336,
#                 loss per word = 3.6068408489227295
#                 loss per mask = 4.008719697594643
#
# я сеичас изучаю французскии . EOS EOS EOS EOS EOS
# i m now learning french . EOS EOS EOS EOS
# MASK m MASK MASK french MASK EOS EOS MASK EOS
# i m not . french EOS EOS EOS EOS EOS
#
# iter 860, loss = 1.6550052165985107 - 0.5279107689857483, masks 1345,
#                 loss per word = 3.578077554702759
#                 loss per mask = 3.924987104255706
#
# я просто планирую на будущее . EOS EOS EOS EOS
# i m simply planning ahead . EOS EOS EOS EOS
# MASK MASK simply MASK MASK MASK EOS EOS MASK EOS
# i m simply . . EOS EOS EOS EOS EOS
#
# iter 870, loss = 1.5570704936981201 - 0.5290976762771606, masks 1224,
#                 loss per word = 3.2634055614471436
#                 loss per mask = 4.322693566791713
#
# мы джексоны . EOS EOS EOS EOS EOS EOS EOS
# we re the jacksons . EOS EOS EOS EOS EOS
# MASK MASK the jacksons . EOS EOS MASK MASK EOS
# i m the jacksons . EOS EOS EOS EOS EOS
#
# iter 880, loss = 1.6342284679412842 - 0.5197190642356873, masks 1351,
#                 loss per word = 3.5381247997283936
#                 loss per mask = 3.846921317745
#
# я в списке тома . EOS EOS EOS EOS EOS
# i m on tom s list . EOS EOS EOS
# i m on tom MASK list . EOS EOS MASK
# i m on tom . list . EOS EOS EOS
#
# iter 890, loss = 1.6951568126678467 - 0.5382772088050842, masks 1354,
#                 loss per word = 3.672633647918701
#                 loss per mask = 3.975459549110383
#
# я вечером работаю . EOS EOS EOS EOS EOS EOS
# i m working tonight . EOS EOS EOS EOS EOS
# MASK MASK working tonight MASK EOS MASK EOS EOS MASK
# i m working tonight . EOS EOS EOS EOS EOS
#
# iter 900, loss = 1.7072601318359375 - 0.5426625609397888, masks 1352,
#                 loss per word = 3.6971347332000732
#                 loss per mask = 4.0137761970981956
#
# я голодна . а ты ? EOS EOS EOS EOS
# i m hungry . what about you ? EOS EOS
# MASK MASK MASK MASK MASK MASK you MASK MASK MASK
# i m not . . EOS you EOS EOS EOS
#
# iter 910, loss = 1.6000293493270874 - 0.5344732999801636, masks 1256,
#                 loss per word = 3.3827176094055176
#                 loss per mask = 4.2553606908768415
#
# она нынче ушла . EOS EOS EOS EOS EOS EOS
# she is out now . EOS EOS EOS EOS EOS
# she is out now . EOS MASK MASK EOS MASK
# she is out now . EOS EOS EOS EOS EOS
#
# iter 920, loss = 1.6305677890777588 - 0.5289559960365295, masks 1312,
#                 loss per word = 3.497180223464966
#                 loss per mask = 4.031676799058914
#
# ты аморален . EOS EOS EOS EOS EOS EOS EOS
# you re immoral . EOS EOS EOS EOS EOS EOS
# MASK re MASK MASK EOS EOS MASK MASK MASK EOS
# i re not . EOS EOS EOS EOS EOS EOS
#
# iter 930, loss = 1.6950905323028564 - 0.5493342280387878, masks 1314,
#                 loss per word = 3.6373212337493896
#                 loss per mask = 4.180625837761909
#
# я уверен что том извинится . EOS EOS EOS EOS
# i m sure tom will apologize . EOS EOS EOS
# MASK m MASK tom will MASK MASK MASK MASK MASK
# i m not tom will EOS EOS EOS EOS EOS
#
# iter 940, loss = 1.6072351932525635 - 0.514249861240387, masks 1339,
#                 loss per word = 3.469794750213623
#                 loss per mask = 3.8405516534112394
#
# потом мы собираемся поехать в бостон . EOS EOS EOS
# we re going to go to boston next . EOS
# we MASK going MASK MASK to MASK next MASK MASK
# we m going . . to EOS next EOS EOS
# iter 950, loss = 1.635324239730835 - 0.5179453492164612, masks 1359,
#                 loss per word = 3.547234535217285
#                 loss per mask = 3.8112240144982934
#
# я преподаватель тома по французскому . EOS EOS EOS EOS
# i m tom s french teacher . EOS EOS EOS
# MASK m MASK s MASK teacher . MASK EOS MASK
# i m not s . teacher . EOS EOS EOS
#
# iter 960, loss = 1.6549147367477417 - 0.5260317325592041, masks 1352,
#                 loss per word = 3.5837554931640625
#                 loss per mask = 3.890767111442983
#
# я вряд ли выиграю . EOS EOS EOS EOS EOS
# i m not likely to win . EOS EOS EOS
# i m not likely MASK win . MASK MASK MASK
# i m not likely . win . EOS EOS EOS
#
# iter 970, loss = 1.7186903953552246 - 0.5518717169761658, masks 1332,
#                 loss per word = 3.704185962677002
#                 loss per mask = 4.14318114053458
#
# я сеичас очень зол . EOS EOS EOS EOS EOS
# i m very angry now . EOS EOS EOS EOS
# MASK MASK MASK MASK MASK . EOS EOS EOS EOS
# i m not . . . EOS EOS EOS EOS
#
# iter 980, loss = 1.6896225214004517 - 0.5450249910354614, masks 1323,
#                 loss per word = 3.6336429119110107
#                 loss per mask = 4.11961431382224
#
# мы разводимся . EOS EOS EOS EOS EOS EOS EOS
# we re getting divorced . EOS EOS EOS EOS EOS
# MASK re MASK divorced MASK MASK MASK MASK EOS EOS
# i re not divorced . EOS EOS EOS EOS EOS
