# %% [markdown]
# Дана статистика пользователей adult.csv.
# Получите значения AUC для различных моделей и их параметров.
# Используйте как минимум 3 различные модели классификации.

# %%
from sklearn.linear_model import LogisticRegression as lr
from sklearn.ensemble import RandomForestClassifier as rf
from sklearn.neighbors import KNeighborsClassifier as kn
from sklearn.tree import DecisionTreeClassifier as dt
from sklearn.metrics import roc_auc_score, roc_curve
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
import matplotlib.pyplot as plt
from itertools import product
import pandas as pd
import numpy as np
import warnings

# %%
warnings.filterwarnings("ignore")

# %%
data = pd.read_csv("adult.csv")
target = 'income'

# %%
data[data.isnull()].count()
# пропусков нет
# Out:
# age                0
# workclass          0
# fnlwgt             0
# education          0
# educational-num    0
# marital-status     0
# occupation         0
# relationship       0
# race               0
# gender             0
# capital-gain       0
# capital-loss       0
# hours-per-week     0
# native-country     0
# income             0
# dtype: int64

# %%
data2 = data.copy()

# LE
le = LabelEncoder()
for i in data.columns:
    if (len(du:= data[i].unique()) < 200) and (data[i].dtype == 'O'):
        print(f'LE   {i}\n{du}\n')
        data[i] = le.fit_transform(data[i])
    else:
        print(f'pass {i}\n{du}\n')
# Out:
# pass age
# [25 38 28 44 18 34 29 63 24 55 65 36 26 58 48 43 20 37 40 72 45 22 23 54
#  32 46 56 17 39 52 21 42 33 30 47 41 19 69 50 31 59 49 51 27 57 61 64 79
#  73 53 77 80 62 35 68 66 75 60 67 71 70 90 81 74 78 82 83 85 76 84 89 88
#  87 86]
#
# LE   workclass
# ['Private' 'Local-gov' '?' 'Self-emp-not-inc' 'Federal-gov' 'State-gov'
#  'Self-emp-inc' 'Without-pay' 'Never-worked']
#
# pass fnlwgt
# [226802  89814 336951 ... 129912 255835 257302]
#
# LE   education
# ['11th' 'HS-grad' 'Assoc-acdm' 'Some-college' '10th' 'Prof-school'
#  '7th-8th' 'Bachelors' 'Masters' 'Doctorate' '5th-6th' 'Assoc-voc' '9th'
#  '12th' '1st-4th' 'Preschool']
#
# pass educational-num
# [ 7  9 12 10  6 15  4 13 14 16  3 11  5  8  2  1]
#
# LE   marital-status
# ['Never-married' 'Married-civ-spouse' 'Widowed' 'Divorced' 'Separated'
#  'Married-spouse-absent' 'Married-AF-spouse']
#
# LE   occupation
# ['Machine-op-inspct' 'Farming-fishing' 'Protective-serv' '?'
#  'Other-service' 'Prof-specialty' 'Craft-repair' 'Adm-clerical'
#  'Exec-managerial' 'Tech-support' 'Sales' 'Priv-house-serv'
#  'Transport-moving' 'Handlers-cleaners' 'Armed-Forces']
#
# LE   relationship
# ['Own-child' 'Husband' 'Not-in-family' 'Unmarried' 'Wife' 'Other-relative']
#
# LE   race
# ['Black' 'White' 'Asian-Pac-Islander' 'Other' 'Amer-Indian-Eskimo']
#
# LE   gender
# ['Male' 'Female']
#
# pass capital-gain
# [    0  7688  3103  6418  7298  3908 14084  5178 15024 99999  2597  2907
#   4650  6497  1055  5013 27828  4934  4064  3674  2174 10605  3418   114
#   2580  3411  4508  4386  8614 13550  6849  2463  3137  2885  2964  1471
#  10566  2354  1424  1455  3325  4416 25236   594  2105  4787  2829   401
#   4865  1264  1506 10520  3464  2653 20051  4101  1797  2407  3471  1086
#   1848 14344  1151  2993  2290 15020  9386  2202  3818  2176  5455 11678
#   7978  7262  6514 41310  3456  7430  2414  2062 34095  1831  6723  5060
#  15831  2977  2346  3273  2329  9562  2635  4931  1731  6097   914  7896
#   5556  1409  3781  3942  2538  3887 25124  7443  5721  1173  4687  6612
#   6767  2961   991  2036  2936  2050  1111  2228 22040  3432  6360  2009
#   1639 18481  2387]
#
# pass capital-loss
# [   0 1721 1876 2415 1887  625 1977 2057 1429 1590 1485 2051 2377 1672
#  1628 1902 1602 1741 2444 1408 2001 2042 1740 1825 1848 1719 3004 2179
#  1573 2205 1258 2339 1726 2258 1340 1504 2559 1668 1974 1980 1564 2547
#  2002 1669 1617  323 3175 2472 2174 1579 2129 1510 1735 2282 1870 1411
#  1911 1651 1092 1762 2457 2231 2238  653 1138 2246 2603 2392 1944 1380
#  2465 1421 3770 1594  213 2149 2824 1844 2467 2163 1816 1648 2206 2352
#   419 1539  880  810  974 4356 2489 1755 3683 2267 2080  155 3900 2201
#  2754]
#
# pass hours-per-week
# [40 50 30 32 10 39 35 48 25 20 45 47  6 43 90 54 60 38 36 18 24 44 56 28
#  16 41 22 55 14 33 37  8 12 70 15 75 52 84 42 80 68 99 65  5 17 72 53 29
#  96 21 46  3  1 23 49 67 76  7  2 58 26 34  4 51 78 63 31 92 77 27 85 13
#  19 98 62 66 57 11 86 59  9 64 73 61 88 79 89 74 69 87 97 94 82 91 81 95]
#
# LE   native-country
# ['United-States' '?' 'Peru' 'Guatemala' 'Mexico' 'Dominican-Republic'
#  'Ireland' 'Germany' 'Philippines' 'Thailand' 'Haiti' 'El-Salvador'
#  'Puerto-Rico' 'Vietnam' 'South' 'Columbia' 'Japan' 'India' 'Cambodia'
#  'Poland' 'Laos' 'England' 'Cuba' 'Taiwan' 'Italy' 'Canada' 'Portugal'
#  'China' 'Nicaragua' 'Honduras' 'Iran' 'Scotland' 'Jamaica' 'Ecuador'
#  'Yugoslavia' 'Hungary' 'Hong' 'Greece' 'Trinadad&Tobago'
#  'Outlying-US(Guam-USVI-etc)' 'France' 'Holand-Netherlands']
#
# LE   income
# ['<=50K' '>50K']

# %%
data
# Out:
#        age  workclass  fnlwgt  education  educational-num  marital-status  \
# 0       25          4  226802          1                7               4
# 1       38          4   89814         11                9               2
# 2       28          2  336951          7               12               2
# 3       44          4  160323         15               10               2
# 4       18          0  103497         15               10               4
# ...    ...        ...     ...        ...              ...             ...
# 48837   27          4  257302          7               12               2
# 48838   40          4  154374         11                9               2
# 48839   58          4  151910         11                9               6
# 48840   22          4  201490         11                9               4
# 48841   52          5  287927         11                9               2
#
#        occupation  relationship  race  gender  capital-gain  capital-loss  \
# 0               7             3     2       1             0             0
# 1               5             0     4       1             0             0
# 2              11             0     4       1             0             0
# 3               7             0     2       1          7688             0
# 4               0             3     4       0             0             0
# ...           ...           ...   ...     ...           ...           ...
# 48837          13             5     4       0             0             0
# 48838           7             0     4       1             0             0
# 48839           1             4     4       0             0             0
# 48840           1             3     4       1             0             0
# 48841           4             5     4       0         15024             0
#
#        hours-per-week  native-country  income
# 0                  40              39       0
# 1                  50              39       0
# 2                  40              39       1
# 3                  40              39       1
# 4                  30              39       0
# ...               ...             ...     ...
# 48837              38              39       0
# 48838              40              39       1
# 48839              40              39       0
# 48840              20              39       0
# 48841              40              39       1
#
# [48842 rows x 15 columns]

# %%
X = data.drop((Y:= data[target]).name, axis=1)
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3)

# %%
models = [lr, rf, kn, dt]
results = pd.DataFrame(columns=['estimator', 'auc_score', 'params'])

# %%
# LogisticRegression

m = models[0]
print(estimator:= m.__name__)

solver_s = ['newton-cg', 'lbfgs', 'liblinear', 'sag', 'saga']
max_iter_s = 10**np.arange(3)

for par in product(solver_s, max_iter_s):
    params = {'solver':par[0], 'max_iter':par[1]}
    Y_pred_prob = m(**params).fit(X_train, Y_train).predict_proba(X_test)
    print('roc_auc_score', (auc_score:= roc_auc_score(Y_test, Y_pred_prob[:,1])), params)
    results = results.append({'estimator':estimator, 'auc_score':auc_score, 'params':params}, ignore_index=True)
# Out:
# LogisticRegression
# roc_auc_score 0.5046840525510642 {'solver': 'newton-cg', 'max_iter': 1}
# roc_auc_score 0.6272034845661056 {'solver': 'newton-cg', 'max_iter': 10}
# roc_auc_score 0.8539178130811511 {'solver': 'newton-cg', 'max_iter': 100}
# roc_auc_score 0.5046840525510642 {'solver': 'lbfgs', 'max_iter': 1}
# roc_auc_score 0.5925905037424035 {'solver': 'lbfgs', 'max_iter': 10}
# roc_auc_score 0.7268682511867268 {'solver': 'lbfgs', 'max_iter': 100}
# roc_auc_score 0.5046840525510642 {'solver': 'liblinear', 'max_iter': 1}
# roc_auc_score 0.6334106606133966 {'solver': 'liblinear', 'max_iter': 10}
# roc_auc_score 0.7153305071720629 {'solver': 'liblinear', 'max_iter': 100}
# roc_auc_score 0.5480200298942096 {'solver': 'sag', 'max_iter': 1}
# roc_auc_score 0.5949316005028626 {'solver': 'sag', 'max_iter': 10}
# roc_auc_score 0.6113766565403118 {'solver': 'sag', 'max_iter': 100}
# roc_auc_score 0.5425488790525538 {'solver': 'saga', 'max_iter': 1}
# roc_auc_score 0.5826103255257249 {'solver': 'saga', 'max_iter': 10}
# roc_auc_score 0.6064944163024685 {'solver': 'saga', 'max_iter': 100}

# %%
# RandomForestClassifier

m = models[1]
print(estimator:= m.__name__)

n_estimators = 10**np.arange(3)
max_depth = 10**np.arange(3)
criterion = ['gini', 'entropy']
max_features = ['auto', 'sqrt', 'log2']
class_weight = ['balanced', 'balanced_subsample']

for par in product(n_estimators, max_depth, criterion, max_features, class_weight):
    params = {'n_estimators':par[0], 
              'max_depth':par[1],
              'criterion':par[2],
              'max_features':par[3],
              'class_weight':par[4]}
    Y_pred_prob = m(**params).fit(X_train, Y_train).predict_proba(X_test)
    print('roc_auc_score', (auc_score:= roc_auc_score(Y_test, Y_pred_prob[:,1])), params,'\n')
    results = results.append({'estimator':estimator, 'auc_score':auc_score, 'params':params}, ignore_index=True)
# Out:
# RandomForestClassifier
# roc_auc_score 0.705279987274185 {'n_estimators': 1, 'max_depth': 1, 'criterion': 'gini', 'max_features': 'auto', 'class_weight': 'balanced'}
#
# roc_auc_score 0.6413988880286547 {'n_estimators': 1, 'max_depth': 1, 'criterion': 'gini', 'max_features': 'auto', 'class_weight': 'balanced_subsample'}
#
# roc_auc_score 0.6413988880286547 {'n_estimators': 1, 'max_depth': 1, 'criterion': 'gini', 'max_features': 'sqrt', 'class_weight': 'balanced'}
#
# roc_auc_score 0.6413988880286547 {'n_estimators': 1, 'max_depth': 1, 'criterion': 'gini', 'max_features': 'sqrt', 'class_weight': 'balanced_subsample'}
#
# roc_auc_score 0.727184864118211 {'n_estimators': 1, 'max_depth': 1, 'criterion': 'gini', 'max_features': 'log2', 'class_weight': 'balanced'}
#
# roc_auc_score 0.727184864118211 {'n_estimators': 1, 'max_depth': 1, 'criterion': 'gini', 'max_features': 'log2', 'class_weight': 'balanced_subsample'}
#
# roc_auc_score 0.6316563014012415 {'n_estimators': 1, 'max_depth': 1, 'criterion': 'entropy', 'max_features': 'auto', 'class_weight': 'balanced'}
#
# roc_auc_score 0.6134627521454088 {'n_estimators': 1, 'max_depth': 1, 'criterion': 'entropy', 'max_features': 'auto', 'class_weight': 'balanced_subsample'}
#
# roc_auc_score 0.6645224721825029 {'n_estimators': 1, 'max_depth': 1, 'criterion': 'entropy', 'max_features': 'sqrt', 'class_weight': 'balanced'}
#
# roc_auc_score 0.5614289128728341 {'n_estimators': 1, 'max_depth': 1, 'criterion': 'entropy', 'max_features': 'sqrt', 'class_weight': 'balanced_subsample'}
#
# roc_auc_score 0.727184864118211 {'n_estimators': 1, 'max_depth': 1, 'criterion': 'entropy', 'max_features': 'log2', 'class_weight': 'balanced'}
#
# roc_auc_score 0.727184864118211 {'n_estimators': 1, 'max_depth': 1, 'criterion': 'entropy', 'max_features': 'log2', 'class_weight': 'balanced_subsample'}
#
# roc_auc_score 0.8756761782520505 {'n_estimators': 1, 'max_depth': 10, 'criterion': 'gini', 'max_features': 'auto', 'class_weight': 'balanced'}
#
# roc_auc_score 0.8844475346773184 {'n_estimators': 1, 'max_depth': 10, 'criterion': 'gini', 'max_features': 'auto', 'class_weight': 'balanced_subsample'}
#
# roc_auc_score 0.8756304561592708 {'n_estimators': 1, 'max_depth': 10, 'criterion': 'gini', 'max_features': 'sqrt', 'class_weight': 'balanced'}
#
# roc_auc_score 0.8840516617443401 {'n_estimators': 1, 'max_depth': 10, 'criterion': 'gini', 'max_features': 'sqrt', 'class_weight': 'balanced_subsample'}
#
# roc_auc_score 0.8725742608433333 {'n_estimators': 1, 'max_depth': 10, 'criterion': 'gini', 'max_features': 'log2', 'class_weight': 'balanced'}
#
# roc_auc_score 0.8862702132473383 {'n_estimators': 1, 'max_depth': 10, 'criterion': 'gini', 'max_features': 'log2', 'class_weight': 'balanced_subsample'}
#
# roc_auc_score 0.8681732330709807 {'n_estimators': 1, 'max_depth': 10, 'criterion': 'entropy', 'max_features': 'auto', 'class_weight': 'balanced'}
#
# roc_auc_score 0.8813138630239457 {'n_estimators': 1, 'max_depth': 10, 'criterion': 'entropy', 'max_features': 'auto', 'class_weight': 'balanced_subsample'}
#
# roc_auc_score 0.8751730719382866 {'n_estimators': 1, 'max_depth': 10, 'criterion': 'entropy', 'max_features': 'sqrt', 'class_weight': 'balanced'}
#
# roc_auc_score 0.8818818344165867 {'n_estimators': 1, 'max_depth': 10, 'criterion': 'entropy', 'max_features': 'sqrt', 'class_weight': 'balanced_subsample'}
#
# roc_auc_score 0.8773208798076215 {'n_estimators': 1, 'max_depth': 10, 'criterion': 'entropy', 'max_features': 'log2', 'class_weight': 'balanced'}
#
# roc_auc_score 0.8772292723288739 {'n_estimators': 1, 'max_depth': 10, 'criterion': 'entropy', 'max_features': 'log2', 'class_weight': 'balanced_subsample'}
#
# roc_auc_score 0.7361264850950249 {'n_estimators': 1, 'max_depth': 100, 'criterion': 'gini', 'max_features': 'auto', 'class_weight': 'balanced'}
#
# roc_auc_score 0.7276496593377502 {'n_estimators': 1, 'max_depth': 100, 'criterion': 'gini', 'max_features': 'auto', 'class_weight': 'balanced_subsample'}
#
# roc_auc_score 0.7294513484525408 {'n_estimators': 1, 'max_depth': 100, 'criterion': 'gini', 'max_features': 'sqrt', 'class_weight': 'balanced'}
#
# roc_auc_score 0.7464196461099969 {'n_estimators': 1, 'max_depth': 100, 'criterion': 'gini', 'max_features': 'sqrt', 'class_weight': 'balanced_subsample'}
#
# roc_auc_score 0.7401380209297652 {'n_estimators': 1, 'max_depth': 100, 'criterion': 'gini', 'max_features': 'log2', 'class_weight': 'balanced'}
#
# roc_auc_score 0.7443506962896923 {'n_estimators': 1, 'max_depth': 100, 'criterion': 'gini', 'max_features': 'log2', 'class_weight': 'balanced_subsample'}
#
# roc_auc_score 0.73354492027298 {'n_estimators': 1, 'max_depth': 100, 'criterion': 'entropy', 'max_features': 'auto', 'class_weight': 'balanced'}
#
# roc_auc_score 0.7404187219207942 {'n_estimators': 1, 'max_depth': 100, 'criterion': 'entropy', 'max_features': 'auto', 'class_weight': 'balanced_subsample'}
#
# roc_auc_score 0.7489047046576391 {'n_estimators': 1, 'max_depth': 100, 'criterion': 'entropy', 'max_features': 'sqrt', 'class_weight': 'balanced'}
#
# roc_auc_score 0.7495511823909047 {'n_estimators': 1, 'max_depth': 100, 'criterion': 'entropy', 'max_features': 'sqrt', 'class_weight': 'balanced_subsample'}
#
# roc_auc_score 0.7501447782531256 {'n_estimators': 1, 'max_depth': 100, 'criterion': 'entropy', 'max_features': 'log2', 'class_weight': 'balanced'}
#
# roc_auc_score 0.7450909168741704 {'n_estimators': 1, 'max_depth': 100, 'criterion': 'entropy', 'max_features': 'log2', 'class_weight': 'balanced_subsample'}
#
# roc_auc_score 0.8495977033642065 {'n_estimators': 10, 'max_depth': 1, 'criterion': 'gini', 'max_features': 'auto', 'class_weight': 'balanced'}
#
# roc_auc_score 0.8402180923727963 {'n_estimators': 10, 'max_depth': 1, 'criterion': 'gini', 'max_features': 'auto', 'class_weight': 'balanced_subsample'}
#
# roc_auc_score 0.826725012913979 {'n_estimators': 10, 'max_depth': 1, 'criterion': 'gini', 'max_features': 'sqrt', 'class_weight': 'balanced'}
#
# roc_auc_score 0.8643073798824097 {'n_estimators': 10, 'max_depth': 1, 'criterion': 'gini', 'max_features': 'sqrt', 'class_weight': 'balanced_subsample'}
#
# roc_auc_score 0.8342723487202914 {'n_estimators': 10, 'max_depth': 1, 'criterion': 'gini', 'max_features': 'log2', 'class_weight': 'balanced'}
#
# roc_auc_score 0.8005360262205651 {'n_estimators': 10, 'max_depth': 1, 'criterion': 'gini', 'max_features': 'log2', 'class_weight': 'balanced_subsample'}
#
# roc_auc_score 0.8194559035788391 {'n_estimators': 10, 'max_depth': 1, 'criterion': 'entropy', 'max_features': 'auto', 'class_weight': 'balanced'}
#
# roc_auc_score 0.8288936469453546 {'n_estimators': 10, 'max_depth': 1, 'criterion': 'entropy', 'max_features': 'auto', 'class_weight': 'balanced_subsample'}
#
# roc_auc_score 0.8457901081608861 {'n_estimators': 10, 'max_depth': 1, 'criterion': 'entropy', 'max_features': 'sqrt', 'class_weight': 'balanced'}
#
# roc_auc_score 0.8260640020869372 {'n_estimators': 10, 'max_depth': 1, 'criterion': 'entropy', 'max_features': 'sqrt', 'class_weight': 'balanced_subsample'}
#
# roc_auc_score 0.856698068030555 {'n_estimators': 10, 'max_depth': 1, 'criterion': 'entropy', 'max_features': 'log2', 'class_weight': 'balanced'}
#
# roc_auc_score 0.8256145941101602 {'n_estimators': 10, 'max_depth': 1, 'criterion': 'entropy', 'max_features': 'log2', 'class_weight': 'balanced_subsample'}
#
# roc_auc_score 0.9120788021776378 {'n_estimators': 10, 'max_depth': 10, 'criterion': 'gini', 'max_features': 'auto', 'class_weight': 'balanced'}
#
# roc_auc_score 0.9118848349917306 {'n_estimators': 10, 'max_depth': 10, 'criterion': 'gini', 'max_features': 'auto', 'class_weight': 'balanced_subsample'}
#
# roc_auc_score 0.9111877991751032 {'n_estimators': 10, 'max_depth': 10, 'criterion': 'gini', 'max_features': 'sqrt', 'class_weight': 'balanced'}
#
# roc_auc_score 0.9137521051632251 {'n_estimators': 10, 'max_depth': 10, 'criterion': 'gini', 'max_features': 'sqrt', 'class_weight': 'balanced_subsample'}
#
# roc_auc_score 0.9126813540431971 {'n_estimators': 10, 'max_depth': 10, 'criterion': 'gini', 'max_features': 'log2', 'class_weight': 'balanced'}
#
# roc_auc_score 0.9118862167033255 {'n_estimators': 10, 'max_depth': 10, 'criterion': 'gini', 'max_features': 'log2', 'class_weight': 'balanced_subsample'}
#
# roc_auc_score 0.9112148053562779 {'n_estimators': 10, 'max_depth': 10, 'criterion': 'entropy', 'max_features': 'auto', 'class_weight': 'balanced'}
# roc_auc_score 0.9108376608959189 {'n_estimators': 10, 'max_depth': 10, 'criterion': 'entropy', 'max_features': 'auto', 'class_weight': 'balanced_subsample'}
#
# roc_auc_score 0.9105958990498395 {'n_estimators': 10, 'max_depth': 10, 'criterion': 'entropy', 'max_features': 'sqrt', 'class_weight': 'balanced'}
#
# roc_auc_score 0.9114392832464053 {'n_estimators': 10, 'max_depth': 10, 'criterion': 'entropy', 'max_features': 'sqrt', 'class_weight': 'balanced_subsample'}
#
# roc_auc_score 0.91089753925204 {'n_estimators': 10, 'max_depth': 10, 'criterion': 'entropy', 'max_features': 'log2', 'class_weight': 'balanced'}
#
# roc_auc_score 0.911798779481392 {'n_estimators': 10, 'max_depth': 10, 'criterion': 'entropy', 'max_features': 'log2', 'class_weight': 'balanced_subsample'}
#
# roc_auc_score 0.8824136677705119 {'n_estimators': 10, 'max_depth': 100, 'criterion': 'gini', 'max_features': 'auto', 'class_weight': 'balanced'}
#
# roc_auc_score 0.8828562802384443 {'n_estimators': 10, 'max_depth': 100, 'criterion': 'gini', 'max_features': 'auto', 'class_weight': 'balanced_subsample'}
#
# roc_auc_score 0.8858523208559417 {'n_estimators': 10, 'max_depth': 100, 'criterion': 'gini', 'max_features': 'sqrt', 'class_weight': 'balanced'}
#
# roc_auc_score 0.8864749703447008 {'n_estimators': 10, 'max_depth': 100, 'criterion': 'gini', 'max_features': 'sqrt', 'class_weight': 'balanced_subsample'}
#
# roc_auc_score 0.8861067944486949 {'n_estimators': 10, 'max_depth': 100, 'criterion': 'gini', 'max_features': 'log2', 'class_weight': 'balanced'}
#
# roc_auc_score 0.8787104545976855 {'n_estimators': 10, 'max_depth': 100, 'criterion': 'gini', 'max_features': 'log2', 'class_weight': 'balanced_subsample'}
#
# roc_auc_score 0.8837195736429921 {'n_estimators': 10, 'max_depth': 100, 'criterion': 'entropy', 'max_features': 'auto', 'class_weight': 'balanced'}
#
# roc_auc_score 0.8819253834538581 {'n_estimators': 10, 'max_depth': 100, 'criterion': 'entropy', 'max_features': 'auto', 'class_weight': 'balanced_subsample'}
#
# roc_auc_score 0.8794765759940623 {'n_estimators': 10, 'max_depth': 100, 'criterion': 'entropy', 'max_features': 'sqrt', 'class_weight': 'balanced'}
#
# roc_auc_score 0.8837589147404059 {'n_estimators': 10, 'max_depth': 100, 'criterion': 'entropy', 'max_features': 'sqrt', 'class_weight': 'balanced_subsample'}
#
# roc_auc_score 0.8827731514444841 {'n_estimators': 10, 'max_depth': 100, 'criterion': 'entropy', 'max_features': 'log2', 'class_weight': 'balanced'}
#
# roc_auc_score 0.8877340738771546 {'n_estimators': 10, 'max_depth': 100, 'criterion': 'entropy', 'max_features': 'log2', 'class_weight': 'balanced_subsample'}
#
# roc_auc_score 0.8535418493561551 {'n_estimators': 100, 'max_depth': 1, 'criterion': 'gini', 'max_features': 'auto', 'class_weight': 'balanced'}
#
# roc_auc_score 0.853338260433141 {'n_estimators': 100, 'max_depth': 1, 'criterion': 'gini', 'max_features': 'auto', 'class_weight': 'balanced_subsample'}
#
# roc_auc_score 0.8643282939715522 {'n_estimators': 100, 'max_depth': 1, 'criterion': 'gini', 'max_features': 'sqrt', 'class_weight': 'balanced'}
#
# roc_auc_score 0.8526934658758185 {'n_estimators': 100, 'max_depth': 1, 'criterion': 'gini', 'max_features': 'sqrt', 'class_weight': 'balanced_subsample'}
#
# roc_auc_score 0.8584890425999774 {'n_estimators': 100, 'max_depth': 1, 'criterion': 'gini', 'max_features': 'log2', 'class_weight': 'balanced'}
#
# roc_auc_score 0.8500488447609843 {'n_estimators': 100, 'max_depth': 1, 'criterion': 'gini', 'max_features': 'log2', 'class_weight': 'balanced_subsample'}
#
# roc_auc_score 0.8495329638954741 {'n_estimators': 100, 'max_depth': 1, 'criterion': 'entropy', 'max_features': 'auto', 'class_weight': 'balanced'}
#
# roc_auc_score 0.8554696259344956 {'n_estimators': 100, 'max_depth': 1, 'criterion': 'entropy', 'max_features': 'auto', 'class_weight': 'balanced_subsample'}
#
# roc_auc_score 0.8535192018470118 {'n_estimators': 100, 'max_depth': 1, 'criterion': 'entropy', 'max_features': 'sqrt', 'class_weight': 'balanced'}
#
# roc_auc_score 0.853259440067154 {'n_estimators': 100, 'max_depth': 1, 'criterion': 'entropy', 'max_features': 'sqrt', 'class_weight': 'balanced_subsample'}
#
# roc_auc_score 0.8477765446769411 {'n_estimators': 100, 'max_depth': 1, 'criterion': 'entropy', 'max_features': 'log2', 'class_weight': 'balanced'}
#
# roc_auc_score 0.8565538299010529 {'n_estimators': 100, 'max_depth': 1, 'criterion': 'entropy', 'max_features': 'log2', 'class_weight': 'balanced_subsample'}
#
# roc_auc_score 0.9151740496876554 {'n_estimators': 100, 'max_depth': 10, 'criterion': 'gini', 'max_features': 'auto', 'class_weight': 'balanced'}
#
# roc_auc_score 0.9153557447623961 {'n_estimators': 100, 'max_depth': 10, 'criterion': 'gini', 'max_features': 'auto', 'class_weight': 'balanced_subsample'}
#
# roc_auc_score 0.9145910804437012 {'n_estimators': 100, 'max_depth': 10, 'criterion': 'gini', 'max_features': 'sqrt', 'class_weight': 'balanced'}
#
# roc_auc_score 0.9143855320024252 {'n_estimators': 100, 'max_depth': 10, 'criterion': 'gini', 'max_features': 'sqrt', 'class_weight': 'balanced_subsample'}
#
# roc_auc_score 0.9143109949423829 {'n_estimators': 100, 'max_depth': 10, 'criterion': 'gini', 'max_features': 'log2', 'class_weight': 'balanced'}
#
# roc_auc_score 0.9155510936598983 {'n_estimators': 100, 'max_depth': 10, 'criterion': 'gini', 'max_features': 'log2', 'class_weight': 'balanced_subsample'}
#
# roc_auc_score 0.9151295460132822 {'n_estimators': 100, 'max_depth': 10, 'criterion': 'entropy', 'max_features': 'auto', 'class_weight': 'balanced'}
#
# roc_auc_score 0.9145385754030919 {'n_estimators': 100, 'max_depth': 10, 'criterion': 'entropy', 'max_features': 'auto', 'class_weight': 'balanced_subsample'}
#
# roc_auc_score 0.9147165524175406 {'n_estimators': 100, 'max_depth': 10, 'criterion': 'entropy', 'max_features': 'sqrt', 'class_weight': 'balanced'}
#
# roc_auc_score 0.9151179521968988 {'n_estimators': 100, 'max_depth': 10, 'criterion': 'entropy', 'max_features': 'sqrt', 'class_weight': 'balanced_subsample'}
#
# roc_auc_score 0.9151935569431735 {'n_estimators': 100, 'max_depth': 10, 'criterion': 'entropy', 'max_features': 'log2', 'class_weight': 'balanced'}
#
# roc_auc_score 0.9152738218258277 {'n_estimators': 100, 'max_depth': 10, 'criterion': 'entropy', 'max_features': 'log2', 'class_weight': 'balanced_subsample'}
#
# roc_auc_score 0.9061428309944138 {'n_estimators': 100, 'max_depth': 100, 'criterion': 'gini', 'max_features': 'auto', 'class_weight': 'balanced'}
#
# roc_auc_score 0.9075826875255208 {'n_estimators': 100, 'max_depth': 100, 'criterion': 'gini', 'max_features': 'auto', 'class_weight': 'balanced_subsample'}
#
# roc_auc_score 0.9084077452019311 {'n_estimators': 100, 'max_depth': 100, 'criterion': 'gini', 'max_features': 'sqrt', 'class_weight': 'balanced'}
#
# roc_auc_score 0.9071549096157129 {'n_estimators': 100, 'max_depth': 100, 'criterion': 'gini', 'max_features': 'sqrt', 'class_weight': 'balanced_subsample'}
#
# roc_auc_score 0.9069894308106914 {'n_estimators': 100, 'max_depth': 100, 'criterion': 'gini', 'max_features': 'log2', 'class_weight': 'balanced'}
#
# roc_auc_score 0.907028771908105 {'n_estimators': 100, 'max_depth': 100, 'criterion': 'gini', 'max_features': 'log2', 'class_weight': 'balanced_subsample'}
#
# roc_auc_score 0.9077632144259131 {'n_estimators': 100, 'max_depth': 100, 'criterion': 'entropy', 'max_features': 'auto', 'class_weight': 'balanced'}
#
# roc_auc_score 0.9073309271118998 {'n_estimators': 100, 'max_depth': 100, 'criterion': 'entropy', 'max_features': 'auto', 'class_weight': 'balanced_subsample'}
#
# roc_auc_score 0.9071679605097782 {'n_estimators': 100, 'max_depth': 100, 'criterion': 'entropy', 'max_features': 'sqrt', 'class_weight': 'balanced'}
#
# roc_auc_score 0.908041604190274 {'n_estimators': 100, 'max_depth': 100, 'criterion': 'entropy', 'max_features': 'sqrt', 'class_weight': 'balanced_subsample'}
#
# roc_auc_score 0.907331467235523 {'n_estimators': 100, 'max_depth': 100, 'criterion': 'entropy', 'max_features': 'log2', 'class_weight': 'balanced'}
#
# roc_auc_score 0.9083316380150763 {'n_estimators': 100, 'max_depth': 100, 'criterion': 'entropy', 'max_features': 'log2', 'class_weight': 'balanced_subsample'}

# %%
# KNeighborsClassifier

m = models[2]
print(estimator:= m.__name__)

n_neighbors = range(2, 55, 10)
weights =  ['uniform', 'distance']
algorithm = ['ball_tree', 'kd_tree', 'brute']

for par in product(n_neighbors, weights, algorithm):
    params = {'n_neighbors':par[0],
              'weights':par[1],
              'algorithm':par[2],}
    Y_pred_prob = m(**params).fit(X_train, Y_train).predict_proba(X_test)
    print('roc_auc_score', (auc_score:= roc_auc_score(Y_test, Y_pred_prob[:,1])), params,'\n')

    results = results.append({'estimator':estimator, 'auc_score':auc_score, 'params':params}, ignore_index=True)
# Out:
# KNeighborsClassifier
# roc_auc_score 0.6720979572223095 {'n_neighbors': 2, 'weights': 'uniform', 'algorithm': 'ball_tree'}
#
# roc_auc_score 0.6719661921802058 {'n_neighbors': 2, 'weights': 'uniform', 'algorithm': 'kd_tree'}
#
# roc_auc_score 0.6716118208391351 {'n_neighbors': 2, 'weights': 'uniform', 'algorithm': 'brute'}
#
# roc_auc_score 0.6791642312953053 {'n_neighbors': 2, 'weights': 'distance', 'algorithm': 'ball_tree'}
#
# roc_auc_score 0.6790359707762472 {'n_neighbors': 2, 'weights': 'distance', 'algorithm': 'kd_tree'}
#
# roc_auc_score 0.6787329991065099 {'n_neighbors': 2, 'weights': 'distance', 'algorithm': 'brute'}
#
# roc_auc_score 0.6707349238558837 {'n_neighbors': 12, 'weights': 'uniform', 'algorithm': 'ball_tree'}
#
# roc_auc_score 0.6707349238558837 {'n_neighbors': 12, 'weights': 'uniform', 'algorithm': 'kd_tree'}
#
# roc_auc_score 0.670801195768385 {'n_neighbors': 12, 'weights': 'uniform', 'algorithm': 'brute'}
#
# roc_auc_score 0.6972523559564406 {'n_neighbors': 12, 'weights': 'distance', 'algorithm': 'ball_tree'}
#
# roc_auc_score 0.6972523559564406 {'n_neighbors': 12, 'weights': 'distance', 'algorithm': 'kd_tree'}
#
# roc_auc_score 0.6972816984863123 {'n_neighbors': 12, 'weights': 'distance', 'algorithm': 'brute'}
#
# roc_auc_score 0.6573792116516373 {'n_neighbors': 22, 'weights': 'uniform', 'algorithm': 'ball_tree'}
#
# roc_auc_score 0.6573744259051129 {'n_neighbors': 22, 'weights': 'uniform', 'algorithm': 'kd_tree'}
#
# roc_auc_score 0.6573677811284424 {'n_neighbors': 22, 'weights': 'uniform', 'algorithm': 'brute'}
#
# roc_auc_score 0.6951328982968319 {'n_neighbors': 22, 'weights': 'distance', 'algorithm': 'ball_tree'}
#
# roc_auc_score 0.695133501225528 {'n_neighbors': 22, 'weights': 'distance', 'algorithm': 'kd_tree'}
#
# roc_auc_score 0.695130360971903 {'n_neighbors': 22, 'weights': 'distance', 'algorithm': 'brute'}
#
# roc_auc_score 0.6561027990412027 {'n_neighbors': 32, 'weights': 'uniform', 'algorithm': 'ball_tree'}
#
# roc_auc_score 0.6560868591138024 {'n_neighbors': 32, 'weights': 'uniform', 'algorithm': 'kd_tree'}
#
# roc_auc_score 0.6560868591138024 {'n_neighbors': 32, 'weights': 'uniform', 'algorithm': 'brute'}
#
# roc_auc_score 0.6953189394825897 {'n_neighbors': 32, 'weights': 'distance', 'algorithm': 'ball_tree'}
#
# roc_auc_score 0.6953120560466437 {'n_neighbors': 32, 'weights': 'distance', 'algorithm': 'kd_tree'}
#
# roc_auc_score 0.6953133875141808 {'n_neighbors': 32, 'weights': 'distance', 'algorithm': 'brute'}
#
# roc_auc_score 0.6487357765980362 {'n_neighbors': 42, 'weights': 'uniform', 'algorithm': 'ball_tree'}
#
# roc_auc_score 0.6487248736374502 {'n_neighbors': 42, 'weights': 'uniform', 'algorithm': 'kd_tree'}
#
# roc_auc_score 0.6487364172097756 {'n_neighbors': 42, 'weights': 'uniform', 'algorithm': 'brute'}
#
# roc_auc_score 0.693636856347867 {'n_neighbors': 42, 'weights': 'distance', 'algorithm': 'ball_tree'}
#
# roc_auc_score 0.6936334648739519 {'n_neighbors': 42, 'weights': 'distance', 'algorithm': 'kd_tree'}
#
# roc_auc_score 0.693634921951634 {'n_neighbors': 42, 'weights': 'distance', 'algorithm': 'brute'}
#
# roc_auc_score 0.6450512542147857 {'n_neighbors': 52, 'weights': 'uniform', 'algorithm': 'ball_tree'}
#
# roc_auc_score 0.6450357790449217 {'n_neighbors': 52, 'weights': 'uniform', 'algorithm': 'kd_tree'}
#
# roc_auc_score 0.6450390072256482 {'n_neighbors': 52, 'weights': 'uniform', 'algorithm': 'brute'}
#
# roc_auc_score 0.6921827179432736 {'n_neighbors': 52, 'weights': 'distance', 'algorithm': 'ball_tree'}
#
# roc_auc_score 0.6921813864757365 {'n_neighbors': 52, 'weights': 'distance', 'algorithm': 'kd_tree'}
#
# roc_auc_score 0.6921817884282006 {'n_neighbors': 52, 'weights': 'distance', 'algorithm': 'brute'}

# %%
# DecisionTreeClassifier

m = models[3]
print(estimator:= m.__name__)

max_depth = 10**np.arange(3)
criterion = ['gini', 'entropy']
max_features = ['auto', 'sqrt', 'log2']
splitter = ['best', 'random']

for par in product(splitter, max_depth, criterion, max_features):
    params = {'splitter':par[0],
              'max_depth':par[1],
              'criterion':par[2],
              'max_features':par[3]}
    Y_pred_prob = m(**params).fit(X_train, Y_train).predict_proba(X_test)
    print('roc_auc_score', (auc_score:= roc_auc_score(Y_test, Y_pred_prob[:,1])), params,'\n')

    results = results.append({'estimator':estimator, 'auc_score':auc_score, 'params':params}, ignore_index=True)
# Out:
# DecisionTreeClassifier
# roc_auc_score 0.705279987274185 {'splitter': 'best', 'max_depth': 1, 'criterion': 'gini', 'max_features': 'auto'}
#
# roc_auc_score 0.6569114269106471 {'splitter': 'best', 'max_depth': 1, 'criterion': 'gini', 'max_features': 'sqrt'}
#
# roc_auc_score 0.5870908519588476 {'splitter': 'best', 'max_depth': 1, 'criterion': 'gini', 'max_features': 'log2'}
#
# roc_auc_score 0.5614289128728341 {'splitter': 'best', 'max_depth': 1, 'criterion': 'entropy', 'max_features': 'auto'}
#
# roc_auc_score 0.727184864118211 {'splitter': 'best', 'max_depth': 1, 'criterion': 'entropy', 'max_features': 'sqrt'}
#
# roc_auc_score 0.727184864118211 {'splitter': 'best', 'max_depth': 1, 'criterion': 'entropy', 'max_features': 'log2'}
#
# roc_auc_score 0.8885188735020929 {'splitter': 'best', 'max_depth': 10, 'criterion': 'gini', 'max_features': 'auto'}
#
# roc_auc_score 0.8795262422453949 {'splitter': 'best', 'max_depth': 10, 'criterion': 'gini', 'max_features': 'sqrt'}
#
# roc_auc_score 0.8880087455812236 {'splitter': 'best', 'max_depth': 10, 'criterion': 'gini', 'max_features': 'log2'}
#
# roc_auc_score 0.891003781317561 {'splitter': 'best', 'max_depth': 10, 'criterion': 'entropy', 'max_features': 'auto'}
#
# roc_auc_score 0.881438556214886 {'splitter': 'best', 'max_depth': 10, 'criterion': 'entropy', 'max_features': 'sqrt'}
#
# roc_auc_score 0.8931033423302019 {'splitter': 'best', 'max_depth': 10, 'criterion': 'entropy', 'max_features': 'log2'}
#
# roc_auc_score 0.7449318944306019 {'splitter': 'best', 'max_depth': 100, 'criterion': 'gini', 'max_features': 'auto'}
#
# roc_auc_score 0.744920087076972 {'splitter': 'best', 'max_depth': 100, 'criterion': 'gini', 'max_features': 'sqrt'}
#
# roc_auc_score 0.7430251826735778 {'splitter': 'best', 'max_depth': 100, 'criterion': 'gini', 'max_features': 'log2'}
#
# roc_auc_score 0.7518245250391513 {'splitter': 'best', 'max_depth': 100, 'criterion': 'entropy', 'max_features': 'auto'}
#
# roc_auc_score 0.7451801251991486 {'splitter': 'best', 'max_depth': 100, 'criterion': 'entropy', 'max_features': 'sqrt'}
#
# roc_auc_score 0.7500531833353925 {'splitter': 'best', 'max_depth': 100, 'criterion': 'entropy', 'max_features': 'log2'}
#
# roc_auc_score 0.705279987274185 {'splitter': 'random', 'max_depth': 1, 'criterion': 'gini', 'max_features': 'auto'}
#
# roc_auc_score 0.5955375312813225 {'splitter': 'random', 'max_depth': 1, 'criterion': 'gini', 'max_features': 'sqrt'}
#
# roc_auc_score 0.6134627521454088 {'splitter': 'random', 'max_depth': 1, 'criterion': 'gini', 'max_features': 'log2'}
#
# roc_auc_score 0.5474283809892361 {'splitter': 'random', 'max_depth': 1, 'criterion': 'entropy', 'max_features': 'auto'}
#
# roc_auc_score 0.5840693878480022 {'splitter': 'random', 'max_depth': 1, 'criterion': 'entropy', 'max_features': 'sqrt'}
#
# roc_auc_score 0.727184864118211 {'splitter': 'random', 'max_depth': 1, 'criterion': 'entropy', 'max_features': 'log2'}
#
# roc_auc_score 0.8474937962405487 {'splitter': 'random', 'max_depth': 10, 'criterion': 'gini', 'max_features': 'auto'}
#
# roc_auc_score 0.8271848842158342 {'splitter': 'random', 'max_depth': 10, 'criterion': 'gini', 'max_features': 'sqrt'}
#
# roc_auc_score 0.8284286758716125 {'splitter': 'random', 'max_depth': 10, 'criterion': 'gini', 'max_features': 'log2'}
#
# roc_auc_score 0.8495264447289486 {'splitter': 'random', 'max_depth': 10, 'criterion': 'entropy', 'max_features': 'auto'}
#
# roc_auc_score 0.8255297193351847 {'splitter': 'random', 'max_depth': 10, 'criterion': 'entropy', 'max_features': 'sqrt'}
#
# roc_auc_score 0.827254535041236 {'splitter': 'random', 'max_depth': 10, 'criterion': 'entropy', 'max_features': 'log2'}
#
# roc_auc_score 0.7299745775115334 {'splitter': 'random', 'max_depth': 100, 'criterion': 'gini', 'max_features': 'auto'}
#
# roc_auc_score 0.7210298665251524 {'splitter': 'random', 'max_depth': 100, 'criterion': 'gini', 'max_features': 'sqrt'}
#
# roc_auc_score 0.7377293333502823 {'splitter': 'random', 'max_depth': 100, 'criterion': 'gini', 'max_features': 'log2'}
#
# roc_auc_score 0.7289237984045601 {'splitter': 'random', 'max_depth': 100, 'criterion': 'entropy', 'max_features': 'auto'}
#
# roc_auc_score 0.7348438170993693 {'splitter': 'random', 'max_depth': 100, 'criterion': 'entropy', 'max_features': 'sqrt'}
#
# roc_auc_score 0.7245012033703112 {'splitter': 'random', 'max_depth': 100, 'criterion': 'entropy', 'max_features': 'log2'}

# %%
results.sort_values(by='auc_score', ascending=False)
# Out:
#                   estimator  auc_score  \
# 212  RandomForestClassifier   0.915551
# 208  RandomForestClassifier   0.915356
# 218  RandomForestClassifier   0.915274
# 217  RandomForestClassifier   0.915194
# 207  RandomForestClassifier   0.915174
# ..                      ...        ...
# 253  DecisionTreeClassifier   0.547428
# 12       LogisticRegression   0.542549
# 6        LogisticRegression   0.504684
# 3        LogisticRegression   0.504684
# 0        LogisticRegression   0.504684
#
#                                                 params
# 212  {'n_estimators': 100, 'max_depth': 10, 'criter...
# 208  {'n_estimators': 100, 'max_depth': 10, 'criter...
# 218  {'n_estimators': 100, 'max_depth': 10, 'criter...
# 217  {'n_estimators': 100, 'max_depth': 10, 'criter...
# 207  {'n_estimators': 100, 'max_depth': 10, 'criter...
# ..                                                 ...
# 253  {'splitter': 'random', 'max_depth': 1, 'criter...
# 12                   {'solver': 'saga', 'max_iter': 1}
# 6               {'solver': 'liblinear', 'max_iter': 1}
# 3                   {'solver': 'lbfgs', 'max_iter': 1}
# 0               {'solver': 'newton-cg', 'max_iter': 1}
#
# [542 rows x 3 columns]

# %%
best_result = pd.DataFrame()
for es in results.estimator.unique():
    best_result = best_result.append(results[results.estimator == es].sort_values(by='auc_score', ascending=False).head(1), ignore_index = True)

# %%
best_result.sort_values(by='auc_score', ascending=False)
# Out:
#                 estimator  auc_score  \
# 1  RandomForestClassifier   0.915551
# 2  DecisionTreeClassifier   0.893103
# 0      LogisticRegression   0.853918
# 3    KNeighborsClassifier   0.698599
#
#                                               params
# 1  {'n_estimators': 100, 'max_depth': 10, 'criter...
# 2  {'splitter': 'best', 'max_depth': 10, 'criteri...
# 0           {'solver': 'newton-cg', 'max_iter': 100}
# 3  {'n_neighbors': 8, 'weights': 'distance', 'alg...
